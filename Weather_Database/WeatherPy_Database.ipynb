# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000,size=2000)
lats_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
# If the city is unique, then we will add it to the cities list.    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 752

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters 
record_count = 1
set_count = 1


# Loop through all the cities in our list.
for i,city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.   
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | broome
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | mombasa
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | vaitape
# Processing Record 13 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 1 | fairhope
# Processing Record 15 of Set 1 | holme
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | tornio
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | airai
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | gat
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | lata
# Processing Record 25 of Set 1 | hay river
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | cabo san lucas
# Processing Record 28 of Set 1 | derzhavinsk
# Processing Record 29 of Set 1 | paamiut
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | hamilton
# Processing Record 34 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 1 | san ignacio
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | port lincoln
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | bardiyah
# Processing Record 42 of Set 1 | westport
# Processing Record 43 of Set 1 | itarema
# Processing Record 44 of Set 1 | opportunity
# Processing Record 45 of Set 1 | ixtapa
# Processing Record 46 of Set 1 | salalah
# Processing Record 47 of Set 1 | pingliang
# Processing Record 48 of Set 1 | pangnirtung
# Processing Record 49 of Set 1 | coquimbo
# Processing Record 50 of Set 1 | ocampo
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | kintampo
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | rocha
# Processing Record 5 of Set 2 | gayeri
# Processing Record 6 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | hermon
# Processing Record 9 of Set 2 | hambantota
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 2 | elizabeth city
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | muroto
# Processing Record 15 of Set 2 | ustrzyki dolne
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 2 | bengkulu
# Processing Record 19 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 2 | deputatskiy
# Processing Record 21 of Set 2 | lady frere
# Processing Record 22 of Set 2 | black river
# Processing Record 23 of Set 2 | henties bay
# Processing Record 24 of Set 2 | myaundzha
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | karsava
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | yumen
# Processing Record 29 of Set 2 | beringovskiy
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | atescatempa
# Processing Record 32 of Set 2 | vostok
# Processing Record 33 of Set 2 | chapais
# Processing Record 34 of Set 2 | margate
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | shambu
# Processing Record 39 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 2 | bose
# Processing Record 41 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 2 | fort wellington
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | nerchinskiy zavod
# Processing Record 45 of Set 2 | qasigiannguit
# Processing Record 46 of Set 2 | cape town
# Processing Record 47 of Set 2 | cervo
# Processing Record 48 of Set 2 | pontal do parana
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | visegrad
# Processing Record 2 of Set 3 | verkhnyaya inta
# Processing Record 3 of Set 3 | port hawkesbury
# Processing Record 4 of Set 3 | ahipara
# Processing Record 5 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 6 of Set 3 | mporokoso
# Processing Record 7 of Set 3 | haverfordwest
# Processing Record 8 of Set 3 | arlit
# Processing Record 9 of Set 3 | quatre cocos
# Processing Record 10 of Set 3 | atambua
# Processing Record 11 of Set 3 | huarmey
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | berlevag
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | geraldton
# Processing Record 16 of Set 3 | kungurtug
# Processing Record 17 of Set 3 | hovd
# Processing Record 18 of Set 3 | jumla
# Processing Record 19 of Set 3 | santa fe
# Processing Record 20 of Set 3 | sinnamary
# Processing Record 21 of Set 3 | pombas
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | khatanga
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | saint-leu
# Processing Record 26 of Set 3 | sobolevo
# Processing Record 27 of Set 3 | layou
# Processing Record 28 of Set 3 | sisimiut
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | miri
# Processing Record 31 of Set 3 | sioux lookout
# Processing Record 32 of Set 3 | sao joao da barra
# Processing Record 33 of Set 3 | ciudad bolivar
# Processing Record 34 of Set 3 | cordoba
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 37 of Set 3 | thames
# Processing Record 38 of Set 3 | morros
# Processing Record 39 of Set 3 | eravur
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 3 | yarada
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | anadyr
# Processing Record 45 of Set 3 | srednekolymsk
# Processing Record 46 of Set 3 | labuhan
# Processing Record 47 of Set 3 | bilibino
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | san patricio
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | batemans bay
# Processing Record 3 of Set 4 | komsomolskiy
# Processing Record 4 of Set 4 | trindade
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | anloga
# Processing Record 7 of Set 4 | senno
# Processing Record 8 of Set 4 | brae
# Processing Record 9 of Set 4 | ust-nera
# Processing Record 10 of Set 4 | avera
# Processing Record 11 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 4 | iqaluit
# Processing Record 13 of Set 4 | nikolskoye
# Processing Record 14 of Set 4 | ada
# Processing Record 15 of Set 4 | albany
# Processing Record 16 of Set 4 | whitehorse
# Processing Record 17 of Set 4 | bulalacao
# Processing Record 18 of Set 4 | touros
# Processing Record 19 of Set 4 | broken hill
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | hudson bay
# Processing Record 23 of Set 4 | rapid valley
# Processing Record 24 of Set 4 | kokoda
# Processing Record 25 of Set 4 | constitucion
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | fukue
# Processing Record 28 of Set 4 | bella union
# Processing Record 29 of Set 4 | doha
# Processing Record 30 of Set 4 | antofagasta
# Processing Record 31 of Set 4 | sukpak
# Processing Record 32 of Set 4 | esperance
# Processing Record 33 of Set 4 | walvis bay
# Processing Record 34 of Set 4 | galle
# Processing Record 35 of Set 4 | bud
# Processing Record 36 of Set 4 | oranjestad
# Processing Record 37 of Set 4 | carballo
# Processing Record 38 of Set 4 | bafoulabe
# Processing Record 39 of Set 4 | sitka
# Processing Record 40 of Set 4 | portland
# Processing Record 41 of Set 4 | hasaki
# Processing Record 42 of Set 4 | yabelo
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | kyabe
# Processing Record 45 of Set 4 | viana
# Processing Record 46 of Set 4 | khandyga
# Processing Record 47 of Set 4 | san jeronimo
# Processing Record 48 of Set 4 | new norfolk
# Processing Record 49 of Set 4 | miracema do tocantins
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | panaba
# Processing Record 3 of Set 5 | lukovetskiy
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | tuktoyaktuk
# Processing Record 6 of Set 5 | gamba
# Processing Record 7 of Set 5 | talnakh
# Processing Record 8 of Set 5 | biak
# Processing Record 9 of Set 5 | kita
# Processing Record 10 of Set 5 | ouanaminthe
# Processing Record 11 of Set 5 | sao jose da coroa grande
# Processing Record 12 of Set 5 | poum
# Processing Record 13 of Set 5 | narsaq
# Processing Record 14 of Set 5 | winneba
# Processing Record 15 of Set 5 | lake havasu city
# Processing Record 16 of Set 5 | camargo
# Processing Record 17 of Set 5 | bayji
# Processing Record 18 of Set 5 | ponta delgada
# Processing Record 19 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | singleton
# Processing Record 22 of Set 5 | kavaratti
# Processing Record 23 of Set 5 | kyren
# Processing Record 24 of Set 5 | port macquarie
# Processing Record 25 of Set 5 | the valley
# Processing Record 26 of Set 5 | balykshi
# Processing Record 27 of Set 5 | maridi
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | maputo
# Processing Record 30 of Set 5 | xuddur
# Processing Record 31 of Set 5 | saint george
# Processing Record 32 of Set 5 | lorengau
# Processing Record 33 of Set 5 | van
# Processing Record 34 of Set 5 | waingapu
# Processing Record 35 of Set 5 | inhambane
# Processing Record 36 of Set 5 | awjilah
# Processing Record 37 of Set 5 | pisco
# Processing Record 38 of Set 5 | shubarkuduk
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 41 of Set 5 | tiznit
# Processing Record 42 of Set 5 | ponta do sol
# Processing Record 43 of Set 5 | mumford
# Processing Record 44 of Set 5 | kidal
# Processing Record 45 of Set 5 | igboho
# Processing Record 46 of Set 5 | bend
# Processing Record 47 of Set 5 | kahului
# Processing Record 48 of Set 5 | tukrah
# Processing Record 49 of Set 5 | ostrovnoy
# Processing Record 50 of Set 5 | adrar
# Processing Record 1 of Set 6 | dumalaguing
# Processing Record 2 of Set 6 | arraial do cabo
# Processing Record 3 of Set 6 | coahuayana
# Processing Record 4 of Set 6 | pevek
# Processing Record 5 of Set 6 | la peca
# Processing Record 6 of Set 6 | bethel
# Processing Record 7 of Set 6 | teya
# Processing Record 8 of Set 6 | teguise
# Processing Record 9 of Set 6 | bubaque
# Processing Record 10 of Set 6 | yunyang
# Processing Record 11 of Set 6 | havoysund
# Processing Record 12 of Set 6 | spas-demensk
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | lokosovo
# Processing Record 15 of Set 6 | victoria
# Processing Record 16 of Set 6 | sayyan
# Processing Record 17 of Set 6 | cidreira
# Processing Record 18 of Set 6 | upernavik
# Processing Record 19 of Set 6 | matagami
# Processing Record 20 of Set 6 | aklavik
# Processing Record 21 of Set 6 | okhotsk
# Processing Record 22 of Set 6 | guerrero negro
# Processing Record 23 of Set 6 | pakhtakoron
# Processing Record 24 of Set 6 | padang
# Processing Record 25 of Set 6 | codrington
# Processing Record 26 of Set 6 | gigmoto
# Processing Record 27 of Set 6 | torbay
# Processing Record 28 of Set 6 | paso de carrasco
# Processing Record 29 of Set 6 | cururupu
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | beidao
# Processing Record 32 of Set 6 | rimavska sobota
# Processing Record 33 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 6 | lanzhou
# Processing Record 35 of Set 6 | dali
# Processing Record 36 of Set 6 | buraydah
# Processing Record 37 of Set 6 | ampanihy
# Processing Record 38 of Set 6 | bosaso
# Processing Record 39 of Set 6 | kenai
# Processing Record 40 of Set 6 | kwinana
# Processing Record 41 of Set 6 | stornoway
# Processing Record 42 of Set 6 | northam
# Processing Record 43 of Set 6 | lagoa
# Processing Record 44 of Set 6 | muscat
# Processing Record 45 of Set 6 | aksu
# Processing Record 46 of Set 6 | kavieng
# Processing Record 47 of Set 6 | southbridge
# Processing Record 48 of Set 6 | harper
# Processing Record 49 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 7 | port elizabeth
# Processing Record 2 of Set 7 | smidovich
# Processing Record 3 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 7 | bariadi
# Processing Record 5 of Set 7 | lebu
# Processing Record 6 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 7 | tahoua
# Processing Record 8 of Set 7 | cascais
# Processing Record 9 of Set 7 | burns lake
# Processing Record 10 of Set 7 | karratha
# Processing Record 11 of Set 7 | hvide sande
# Processing Record 12 of Set 7 | bandar-e lengeh
# Processing Record 13 of Set 7 | sawtell
# Processing Record 14 of Set 7 | fortuna
# Processing Record 15 of Set 7 | tremedal
# Processing Record 16 of Set 7 | faanui
# Processing Record 17 of Set 7 | yurino
# Processing Record 18 of Set 7 | kabanjahe
# Processing Record 19 of Set 7 | mecca
# Processing Record 20 of Set 7 | carutapera
# Processing Record 21 of Set 7 | churapcha
# Processing Record 22 of Set 7 | hobyo
# Processing Record 23 of Set 7 | sarakhs
# Processing Record 24 of Set 7 | ereymentau
# Processing Record 25 of Set 7 | valparaiso
# Processing Record 26 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 7 | hithadhoo
# Processing Record 28 of Set 7 | vanimo
# Processing Record 29 of Set 7 | muros
# Processing Record 30 of Set 7 | falkoping
# City not found. Skipping...
# Processing Record 31 of Set 7 | frei paulo
# Processing Record 32 of Set 7 | chiredzi
# Processing Record 33 of Set 7 | praia da vitoria
# Processing Record 34 of Set 7 | kawalu
# Processing Record 35 of Set 7 | hualmay
# Processing Record 36 of Set 7 | ewa beach
# Processing Record 37 of Set 7 | kattivakkam
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | los angeles
# Processing Record 40 of Set 7 | riyadh
# Processing Record 41 of Set 7 | dolores
# Processing Record 42 of Set 7 | shelburne
# Processing Record 43 of Set 7 | eirunepe
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | ust-omchug
# Processing Record 46 of Set 7 | yerbogachen
# Processing Record 47 of Set 7 | sucre
# Processing Record 48 of Set 7 | boa vista
# Processing Record 49 of Set 7 | simao
# Processing Record 50 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 1 of Set 8 | erzurum
# Processing Record 2 of Set 8 | tharad
# Processing Record 3 of Set 8 | mikhaylovskoye
# Processing Record 4 of Set 8 | marsh harbour
# Processing Record 5 of Set 8 | flinders
# Processing Record 6 of Set 8 | ribeira grande
# Processing Record 7 of Set 8 | belmonte
# Processing Record 8 of Set 8 | launceston
# Processing Record 9 of Set 8 | puerto el triunfo
# Processing Record 10 of Set 8 | suez
# Processing Record 11 of Set 8 | vertou
# Processing Record 12 of Set 8 | garhakota
# Processing Record 13 of Set 8 | takoradi
# Processing Record 14 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 8 | tucuman
# Processing Record 16 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 8 | maceio
# Processing Record 18 of Set 8 | kemin
# Processing Record 19 of Set 8 | ratnagiri
# Processing Record 20 of Set 8 | levelland
# Processing Record 21 of Set 8 | kaabong
# Processing Record 22 of Set 8 | candolim
# Processing Record 23 of Set 8 | kudahuvadhoo
# Processing Record 24 of Set 8 | tirumullaivasal
# Processing Record 25 of Set 8 | malakal
# Processing Record 26 of Set 8 | robertsport
# Processing Record 27 of Set 8 | keningau
# Processing Record 28 of Set 8 | monster
# Processing Record 29 of Set 8 | ugoofaaru
# Processing Record 30 of Set 8 | erdaojiang
# Processing Record 31 of Set 8 | semey
# Processing Record 32 of Set 8 | nizwa
# Processing Record 33 of Set 8 | sur
# Processing Record 34 of Set 8 | pundaguitan
# Processing Record 35 of Set 8 | jiamusi
# Processing Record 36 of Set 8 | kitui
# Processing Record 37 of Set 8 | chardara
# Processing Record 38 of Set 8 | yichang
# Processing Record 39 of Set 8 | pochutla
# Processing Record 40 of Set 8 | santos dumont
# Processing Record 41 of Set 8 | marand
# Processing Record 42 of Set 8 | le mars
# Processing Record 43 of Set 8 | ust-kuyga
# Processing Record 44 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 45 of Set 8 | varkaus
# Processing Record 46 of Set 8 | coihaique
# Processing Record 47 of Set 8 | nakonde
# Processing Record 48 of Set 8 | marystown
# Processing Record 49 of Set 8 | severnyy
# Processing Record 50 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 9 | nouakchott
# Processing Record 2 of Set 9 | kamenka
# Processing Record 3 of Set 9 | zhigansk
# Processing Record 4 of Set 9 | santa isabel do rio negro
# Processing Record 5 of Set 9 | hit
# Processing Record 6 of Set 9 | quelimane
# Processing Record 7 of Set 9 | bom jesus
# Processing Record 8 of Set 9 | mersing
# Processing Record 9 of Set 9 | ravar
# Processing Record 10 of Set 9 | akureyri
# Processing Record 11 of Set 9 | buala
# Processing Record 12 of Set 9 | zary
# Processing Record 13 of Set 9 | kantabanji
# Processing Record 14 of Set 9 | mezhova
# Processing Record 15 of Set 9 | jalu
# Processing Record 16 of Set 9 | orangeburg
# Processing Record 17 of Set 9 | cody
# Processing Record 18 of Set 9 | araguaina
# Processing Record 19 of Set 9 | lom sak
# Processing Record 20 of Set 9 | thompson
# Processing Record 21 of Set 9 | isangel
# Processing Record 22 of Set 9 | alofi
# Processing Record 23 of Set 9 | honiara
# Processing Record 24 of Set 9 | porto santo
# Processing Record 25 of Set 9 | north myrtle beach
# Processing Record 26 of Set 9 | kindu
# Processing Record 27 of Set 9 | wasilla
# Processing Record 28 of Set 9 | cockburn town
# Processing Record 29 of Set 9 | samarai
# Processing Record 30 of Set 9 | kaeo
# Processing Record 31 of Set 9 | zhezkazgan
# Processing Record 32 of Set 9 | praya
# Processing Record 33 of Set 9 | barranca
# Processing Record 34 of Set 9 | saint-pierre
# Processing Record 35 of Set 9 | marsa matruh
# Processing Record 36 of Set 9 | mildura
# Processing Record 37 of Set 9 | rogun
# City not found. Skipping...
# Processing Record 38 of Set 9 | champerico
# Processing Record 39 of Set 9 | mut
# Processing Record 40 of Set 9 | fort nelson
# Processing Record 41 of Set 9 | naze
# Processing Record 42 of Set 9 | estreito
# Processing Record 43 of Set 9 | santa cruz
# Processing Record 44 of Set 9 | concepcion del uruguay
# Processing Record 45 of Set 9 | opuwo
# Processing Record 46 of Set 9 | aquiraz
# Processing Record 47 of Set 9 | tarabuco
# Processing Record 48 of Set 9 | san cristobal
# Processing Record 49 of Set 9 | sterling
# Processing Record 50 of Set 9 | vila franca do campo
# Processing Record 1 of Set 10 | kondoa
# Processing Record 2 of Set 10 | muisne
# Processing Record 3 of Set 10 | rudnogorsk
# Processing Record 4 of Set 10 | okahandja
# Processing Record 5 of Set 10 | sao gabriel da cachoeira
# Processing Record 6 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 10 | dzerzhinsk
# Processing Record 8 of Set 10 | fairbanks
# Processing Record 9 of Set 10 | owando
# Processing Record 10 of Set 10 | balabac
# Processing Record 11 of Set 10 | kitovo
# Processing Record 12 of Set 10 | sola
# Processing Record 13 of Set 10 | umm lajj
# Processing Record 14 of Set 10 | vilhena
# Processing Record 15 of Set 10 | olafsvik
# Processing Record 16 of Set 10 | velyka bahachka
# Processing Record 17 of Set 10 | carmelo
# Processing Record 18 of Set 10 | hereford
# Processing Record 19 of Set 10 | langenburg
# Processing Record 20 of Set 10 | kandry
# Processing Record 21 of Set 10 | lavrentiya
# Processing Record 22 of Set 10 | slagelse
# Processing Record 23 of Set 10 | namasuba
# Processing Record 24 of Set 10 | wanaka
# Processing Record 25 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 10 | baripada
# Processing Record 27 of Set 10 | tuatapere
# Processing Record 28 of Set 10 | vao
# Processing Record 29 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 10 | jiayuguan
# Processing Record 31 of Set 10 | kjellerup
# Processing Record 32 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 10 | leh
# Processing Record 34 of Set 10 | zlobin
# Processing Record 35 of Set 10 | karoi
# Processing Record 36 of Set 10 | acapulco
# Processing Record 37 of Set 10 | north bend
# Processing Record 38 of Set 10 | tura
# Processing Record 39 of Set 10 | tarnogskiy gorodok
# Processing Record 40 of Set 10 | aloleng
# Processing Record 41 of Set 10 | kelowna
# Processing Record 42 of Set 10 | mandalgovi
# Processing Record 43 of Set 10 | andarab
# City not found. Skipping...
# Processing Record 44 of Set 10 | jining
# Processing Record 45 of Set 10 | yar-sale
# Processing Record 46 of Set 10 | sumbe
# Processing Record 47 of Set 10 | tiksi
# Processing Record 48 of Set 10 | moranbah
# Processing Record 49 of Set 10 | los llanos de aridane
# Processing Record 50 of Set 10 | bougouni
# Processing Record 1 of Set 11 | oksfjord
# Processing Record 2 of Set 11 | jiangyou
# Processing Record 3 of Set 11 | wa
# City not found. Skipping...
# Processing Record 4 of Set 11 | moctezuma
# Processing Record 5 of Set 11 | oranjemund
# Processing Record 6 of Set 11 | vestmannaeyjar
# Processing Record 7 of Set 11 | te anau
# Processing Record 8 of Set 11 | bonavista
# Processing Record 9 of Set 11 | bognor regis
# Processing Record 10 of Set 11 | dmitriyevka
# Processing Record 11 of Set 11 | suihua
# Processing Record 12 of Set 11 | banjar
# Processing Record 13 of Set 11 | turukhansk
# Processing Record 14 of Set 11 | sandwick
# Processing Record 15 of Set 11 | atar
# Processing Record 16 of Set 11 | vila
# Processing Record 17 of Set 11 | tripoli
# Processing Record 18 of Set 11 | misawa
# Processing Record 19 of Set 11 | vinh
# Processing Record 20 of Set 11 | kisangani
# Processing Record 21 of Set 11 | evensk
# Processing Record 22 of Set 11 | mont-dore
# Processing Record 23 of Set 11 | hulan
# Processing Record 24 of Set 11 | nome
# Processing Record 25 of Set 11 | kerema
# Processing Record 26 of Set 11 | eydhafushi
# Processing Record 27 of Set 11 | moron
# Processing Record 28 of Set 11 | mayor pablo lagerenza
# Processing Record 29 of Set 11 | makuyuni
# Processing Record 30 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 11 | gorontalo
# Processing Record 32 of Set 11 | beaverlodge
# Processing Record 33 of Set 11 | nelson bay
# Processing Record 34 of Set 11 | bavly
# Processing Record 35 of Set 11 | santo domingo
# Processing Record 36 of Set 11 | dunmore east
# Processing Record 37 of Set 11 | nantucket
# Processing Record 38 of Set 11 | pandan
# Processing Record 39 of Set 11 | tanout
# Processing Record 40 of Set 11 | hamina
# Processing Record 41 of Set 11 | ishigaki
# Processing Record 42 of Set 11 | katsuura
# Processing Record 43 of Set 11 | sungairaya
# Processing Record 44 of Set 11 | bonfim
# Processing Record 45 of Set 11 | mount isa
# Processing Record 46 of Set 11 | zapolyarnyy
# Processing Record 47 of Set 11 | hofn
# Processing Record 48 of Set 11 | santona
# Processing Record 49 of Set 11 | ramnagar
# Processing Record 50 of Set 11 | luebo
# Processing Record 1 of Set 12 | caernarfon
# Processing Record 2 of Set 12 | daru
# Processing Record 3 of Set 12 | fuyang
# Processing Record 4 of Set 12 | gboko
# Processing Record 5 of Set 12 | bonthe
# Processing Record 6 of Set 12 | qaqortoq
# Processing Record 7 of Set 12 | lake city
# Processing Record 8 of Set 12 | price
# Processing Record 9 of Set 12 | zambezi
# Processing Record 10 of Set 12 | san rafael
# Processing Record 11 of Set 12 | ulaangom
# Processing Record 12 of Set 12 | mandera
# Processing Record 13 of Set 12 | nongan
# Processing Record 14 of Set 12 | snezhnogorsk
# Processing Record 15 of Set 12 | rajampet
# Processing Record 16 of Set 12 | alice town
# Processing Record 17 of Set 12 | krasnogorsk
# Processing Record 18 of Set 12 | lamu
# Processing Record 19 of Set 12 | dovolnoye
# Processing Record 20 of Set 12 | saint-augustin
# Processing Record 21 of Set 12 | kuldur
# Processing Record 22 of Set 12 | kibaya
# Processing Record 23 of Set 12 | hami
# Processing Record 24 of Set 12 | gainesville
# Processing Record 25 of Set 12 | damghan
# Processing Record 26 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 12 | birao
# Processing Record 28 of Set 12 | omboue
# Processing Record 29 of Set 12 | gladstone
# Processing Record 30 of Set 12 | mao
# Processing Record 31 of Set 12 | acajutla
# Processing Record 32 of Set 12 | morden
# Processing Record 33 of Set 12 | puerto escondido
# Processing Record 34 of Set 12 | carbonia
# Processing Record 35 of Set 12 | sao filipe
# Processing Record 36 of Set 12 | pizhma
# Processing Record 37 of Set 12 | port hardy
# Processing Record 38 of Set 12 | mabaruma
# Processing Record 39 of Set 12 | shingu
# Processing Record 40 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 12 | tezu
# Processing Record 42 of Set 12 | starobaltachevo
# Processing Record 43 of Set 12 | lubango
# Processing Record 44 of Set 12 | vytegra
# Processing Record 45 of Set 12 | tautira
# Processing Record 46 of Set 12 | bokoro
# Processing Record 47 of Set 12 | saldanha
# Processing Record 48 of Set 12 | abonnema
# Processing Record 49 of Set 12 | lebedyn
# Processing Record 50 of Set 12 | morondava
# Processing Record 1 of Set 13 | dudinka
# Processing Record 2 of Set 13 | ichhawar
# Processing Record 3 of Set 13 | petukhovo
# Processing Record 4 of Set 13 | gaoua
# Processing Record 5 of Set 13 | san quintin
# Processing Record 6 of Set 13 | pirapemas
# Processing Record 7 of Set 13 | general pico
# Processing Record 8 of Set 13 | isetskoye
# Processing Record 9 of Set 13 | devin
# Processing Record 10 of Set 13 | lodja
# Processing Record 11 of Set 13 | kalmar
# Processing Record 12 of Set 13 | jiazi
# Processing Record 13 of Set 13 | moose factory
# Processing Record 14 of Set 13 | faya
# Processing Record 15 of Set 13 | ravenna
# Processing Record 16 of Set 13 | seoul
# Processing Record 17 of Set 13 | fallon
# Processing Record 18 of Set 13 | manggar
# Processing Record 19 of Set 13 | kayerkan
# Processing Record 20 of Set 13 | la ronge
# Processing Record 21 of Set 13 | akyab
# Processing Record 22 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 13 | kalamazoo
# Processing Record 24 of Set 13 | verkh-usugli
# Processing Record 25 of Set 13 | gushikawa
# Processing Record 26 of Set 13 | lazaro cardenas
# Processing Record 27 of Set 13 | maragogi
# Processing Record 28 of Set 13 | grafton
# Processing Record 29 of Set 13 | koungou
# Processing Record 30 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 31 of Set 13 | babstovo
# Processing Record 32 of Set 13 | mayo
# Processing Record 33 of Set 13 | araouane
# Processing Record 34 of Set 13 | yarmouth
# Processing Record 35 of Set 13 | zubtsov
# Processing Record 36 of Set 13 | zhireken
# Processing Record 37 of Set 13 | a
# City not found. Skipping...
# Processing Record 38 of Set 13 | tokmak
# Processing Record 39 of Set 13 | taldan
# Processing Record 40 of Set 13 | lardos
# Processing Record 41 of Set 13 | enid
# Processing Record 42 of Set 13 | nioro
# Processing Record 43 of Set 13 | anta
# Processing Record 44 of Set 13 | prince rupert
# Processing Record 45 of Set 13 | khomeynishahr
# City not found. Skipping...
# Processing Record 46 of Set 13 | kjollefjord
# Processing Record 47 of Set 13 | meadow lake
# Processing Record 48 of Set 13 | darnah
# Processing Record 49 of Set 13 | rorvik
# Processing Record 50 of Set 13 | kendari
# Processing Record 1 of Set 14 | teguldet
# Processing Record 2 of Set 14 | mehamn
# Processing Record 3 of Set 14 | san agustin acasaguastlan
# Processing Record 4 of Set 14 | rio gallegos
# Processing Record 5 of Set 14 | popondetta
# Processing Record 6 of Set 14 | okha
# Processing Record 7 of Set 14 | braganca
# Processing Record 8 of Set 14 | zmeinogorsk
# Processing Record 9 of Set 14 | tilichiki
# Processing Record 10 of Set 14 | krasnyy yar
# Processing Record 11 of Set 14 | zhuhai
# Processing Record 12 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 13 of Set 14 | biryusinsk
# Processing Record 14 of Set 14 | muli
# Processing Record 15 of Set 14 | morristown
# Processing Record 16 of Set 14 | les escoumins
# Processing Record 17 of Set 14 | la rioja
# Processing Record 18 of Set 14 | shiyan
# Processing Record 19 of Set 14 | nizhniy odes
# Processing Record 20 of Set 14 | pacific grove
# Processing Record 21 of Set 14 | bathsheba
# Processing Record 22 of Set 14 | altay
# Processing Record 23 of Set 14 | montrose
# Processing Record 24 of Set 14 | macae
# Processing Record 25 of Set 14 | barcelos
# Processing Record 26 of Set 14 | alpinopolis
# Processing Record 27 of Set 14 | gillette
# Processing Record 28 of Set 14 | manga
# Processing Record 29 of Set 14 | hadejia
# Processing Record 30 of Set 14 | portobelo
# Processing Record 31 of Set 14 | emerald
# Processing Record 32 of Set 14 | angoram
# Processing Record 33 of Set 14 | gvardeysk
# Processing Record 34 of Set 14 | krasnoarmeysk
# Processing Record 35 of Set 14 | trinidad
# Processing Record 36 of Set 14 | burnie
# Processing Record 37 of Set 14 | waipawa
# Processing Record 38 of Set 14 | taltal
# Processing Record 39 of Set 14 | pauini
# Processing Record 40 of Set 14 | khasan
# Processing Record 41 of Set 14 | roald
# Processing Record 42 of Set 14 | steamboat springs
# Processing Record 43 of Set 14 | tyukod
# Processing Record 44 of Set 14 | gannan
# Processing Record 45 of Set 14 | milot
# Processing Record 46 of Set 14 | mikhaylovka
# Processing Record 47 of Set 14 | jacareacanga
# Processing Record 48 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 14 | oistins
# Processing Record 50 of Set 14 | mount gambier
# Processing Record 1 of Set 15 | casino
# Processing Record 2 of Set 15 | markivka
# Processing Record 3 of Set 15 | yatou
# Processing Record 4 of Set 15 | kathu
# Processing Record 5 of Set 15 | angoche
# Processing Record 6 of Set 15 | sturgeon falls
# Processing Record 7 of Set 15 | roros
# Processing Record 8 of Set 15 | yaan
# Processing Record 9 of Set 15 | ca mau
# Processing Record 10 of Set 15 | cayeli
# Processing Record 11 of Set 15 | prince george
# Processing Record 12 of Set 15 | kedrovyy
# Processing Record 13 of Set 15 | itaqui
# Processing Record 14 of Set 15 | waiouru
# Processing Record 15 of Set 15 | manzanillo
# Processing Record 16 of Set 15 | salinopolis
# Processing Record 17 of Set 15 | la gloria
# Processing Record 18 of Set 15 | trois-pistoles
# City not found. Skipping...
# Processing Record 19 of Set 15 | xucheng
# Processing Record 20 of Set 15 | pangody
# Processing Record 21 of Set 15 | taoudenni
# Processing Record 22 of Set 15 | gambela
# Processing Record 23 of Set 15 | bataysk
# Processing Record 24 of Set 15 | agdas
# Processing Record 25 of Set 15 | nueva germania
# Processing Record 26 of Set 15 | hearst
# Processing Record 27 of Set 15 | sandviken
# Processing Record 28 of Set 15 | birin
# Processing Record 29 of Set 15 | ternate
# Processing Record 30 of Set 15 | zanjan
# Processing Record 31 of Set 15 | eisiskes
# Processing Record 32 of Set 15 | kuching
# Processing Record 33 of Set 15 | vinces
# Processing Record 34 of Set 15 | half moon bay
# Processing Record 35 of Set 15 | aybak
# City not found. Skipping...
# Processing Record 36 of Set 15 | husavik
# Processing Record 37 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 15 | voskresenskoye
# Processing Record 39 of Set 15 | gryazovets
# Processing Record 40 of Set 15 | zaoyang
# Processing Record 41 of Set 15 | sorland
# Processing Record 42 of Set 15 | burdur
# Processing Record 43 of Set 15 | bacon
# Processing Record 44 of Set 15 | ajdabiya
# Processing Record 45 of Set 15 | ede
# Processing Record 46 of Set 15 | san policarpo
# Processing Record 47 of Set 15 | anchorage
# Processing Record 48 of Set 15 | biltine
# Processing Record 49 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 15 | atagay
# Processing Record 1 of Set 16 | esterhazy
# Processing Record 2 of Set 16 | phan rang
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df = city_data_df[["City", "Country", "Date" ,"Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]]
city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0           Atuona      PF  2022-03-27 23:01:48  -9.8000 -139.0333     78.91
# 1       Bredasdorp      ZA  2022-03-27 23:01:48 -34.5322   20.0403     65.10
# 2      East London      ZA  2022-03-27 23:01:48 -33.0153   27.9116     70.54
# 3           Lompoc      US  2022-03-27 23:01:49  34.6391 -120.4579     64.62
# 4          Qaanaaq      GL  2022-03-27 23:01:49  77.4840  -69.3632      9.82
# ..             ...     ...                  ...      ...       ...       ...
# 692  San Policarpo      PH  2022-03-27 23:19:59  12.1791  125.5072     80.55
# 693      Anchorage      US  2022-03-27 23:15:04  61.2181 -149.9003     42.55
# 694        Biltine      TD  2022-03-27 23:19:59  14.5333   20.9167     72.28
# 695         Atagay      RU  2022-03-27 23:20:00  55.1033   99.3875      5.38
# 696      Esterhazy      CA  2022-03-27 23:21:00  50.6500 -102.0843     29.25
#
#      Humidity  Cloudiness  Wind Speed
# 0          79          60       12.66
# 1          75          36        3.53
# 2          81          76       19.39
# 3          68         100       17.27
# 4          93         100        5.06
# ..        ...         ...         ...
# 692        83          99       10.94
# 693        56         100        6.91
# 694         6           3       17.25
# 695        99          85        2.77
# 696        86          78       12.19
#
# [697 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
